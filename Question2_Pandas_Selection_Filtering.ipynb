# %% [markdown]
# <a href="https://colab.research.google.com/github/Aswitha-K28/python-loops-assignment/blob/masai/Question2_Pandas_Selection_Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Completing the Task:
#
# Add a markdown cell above each code block with a brief one-line explanation of what the step does
# Execute all tasks in the order specified
# Verify all outputs are clearly visible in the notebook

# %%
import pandas as pd

employee_data = {
    "EmployeeID": [201,202,203,204,205,206,207,208,209,210],
    "Name": ["Sarah","Michael","Jennifer","David","Lisa","James","Emma","Robert","Sophia","William"],
    "Department": ["Engineering","Sales","Marketing","Engineering","HR","Sales","Engineering","Marketing","Sales","HR"],
    "Salary": [85000,62000,71000,92000,58000,68000,78000,75000,65000,60000],
    "Performance Score": [4,3,5,5,4,4,3,4,5,3],
    "Years of Service": [5,3,7,8,4,6,2,5,4,3]
}

df = pd.DataFrame(employee_data)

df
# Out:
#    EmployeeID      Name   Department  Salary  Performance Score  \
# 0         201     Sarah  Engineering   85000                  4
# 1         202   Michael        Sales   62000                  3
# 2         203  Jennifer    Marketing   71000                  5
# 3         204     David  Engineering   92000                  5
# 4         205      Lisa           HR   58000                  4
# 5         206     James        Sales   68000                  4
# 6         207      Emma  Engineering   78000                  3
# 7         208    Robert    Marketing   75000                  4
# 8         209    Sophia        Sales   65000                  5
# 9         210   William           HR   60000                  3
#
#    Years of Service
# 0                 5
# 1                 3
# 2                 7
# 3                 8
# 4                 4
# 5                 6
# 6                 2
# 7                 5
# 8                 4
# 9                 3

# %% [markdown]
# Select and display only the Name, Department, and Salary columns.

# %%
df[["Name","Department","Salary"]]
# Out:
#        Name   Department  Salary
# 0     Sarah  Engineering   85000
# 1   Michael        Sales   62000
# 2  Jennifer    Marketing   71000
# 3     David  Engineering   92000
# 4      Lisa           HR   58000
# 5     James        Sales   68000
# 6      Emma  Engineering   78000
# 7    Robert    Marketing   75000
# 8    Sophia        Sales   65000
# 9   William           HR   60000

# %% [markdown]
# Use iloc to display the employee at row position 5.

# %%
df.iloc[[5]]
# Out:
#    EmployeeID   Name Department  Salary  Performance Score  Years of Service
# 5         206  James      Sales   68000                  4                 6

# %% [markdown]
# Set EmployeeID as index and use loc to display employee with EmployeeID 208.

# %%
df_index = df.set_index("EmployeeID")
df_index.loc[[208]]
# Out:
#               Name Department  Salary  Performance Score  Years of Service
# EmployeeID
# 208         Robert  Marketing   75000                  4                 5

# %% [markdown]
# Filter and display all employees from the Engineering department.

# %%
df[df["Department"] == "Engineering"]

# %% [markdown]
# Filter and display employees whose Salary is greater than 70000.

# %%
df[df["Salary"] > 70000]
# Out:
#    EmployeeID      Name   Department  Salary  Performance Score  \
# 0         201     Sarah  Engineering   85000                  4
# 2         203  Jennifer    Marketing   71000                  5
# 3         204     David  Engineering   92000                  5
# 6         207      Emma  Engineering   78000                  3
# 7         208    Robert    Marketing   75000                  4
#
#    Years of Service
# 0                 5
# 2                 7
# 3                 8
# 6                 2
# 7                 5

# %% [markdown]
# Filter employees from Sales department with Performance Score greater than or equal to 4.

# %%
df[(df["Department"] == "Sales") & (df["Performance Score"] >= 4)]
# Out:
#    EmployeeID    Name Department  Salary  Performance Score  Years of Service
# 5         206   James      Sales   68000                  4                 6
# 8         209  Sophia      Sales   65000                  5                 4

# %%
Sort employees by Salary in descending order and display the top 3 highest paid employees.

# %%
df.sort_values(by="Salary", ascending=False).head(3)
# Out:
#    EmployeeID   Name   Department  Salary  Performance Score  Years of Service
# 3         204  David  Engineering   92000                  5                 8
# 0         201  Sarah  Engineering   85000                  4                 5
# 6         207   Emma  Engineering   78000                  3                 2

# %% [markdown]
# Sort employees by Department (ascending) and Salary (descending) within each department.

# %%
df.sort_values(by=["Department","Salary"], ascending=[True, False])
# Out:
#    EmployeeID      Name   Department  Salary  Performance Score  \
# 3         204     David  Engineering   92000                  5
# 0         201     Sarah  Engineering   85000                  4
# 6         207      Emma  Engineering   78000                  3
# 9         210   William           HR   60000                  3
# 4         205      Lisa           HR   58000                  4
# 7         208    Robert    Marketing   75000                  4
# 2         203  Jennifer    Marketing   71000                  5
# 5         206     James        Sales   68000                  4
# 8         209    Sophia        Sales   65000                  5
# 1         202   Michael        Sales   62000                  3
#
#    Years of Service
# 3                 8
# 0                 5
# 6                 2
# 9                 3
# 4                 4
# 7                 5
# 2                 7
# 5                 6
# 8                 4
# 1                 3
